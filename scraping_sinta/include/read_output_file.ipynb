# %%
import os
import pandas as pd

# %%
current_dir = os.getcwd()
parent_dir = os.path.dirname(current_dir)

# %%
data_1_10 = pd.read_csv(f"{parent_dir}\\outputs\\sinta_affiliations_pages_1_10.csv")

# %%
data_1_10
# Out:
#       id   code                                    affiliate_name  \
# 0    384   1001                           Universitas Gadjah Mada
# 1    380   1004                             Universitas Airlangga
# 2    428   2003                          Institut Pertanian Bogor
# 3    430   1002                             Universitas Indonesia
# 4    404   1019                             Universitas Brawijaya
# ..   ...    ...                                               ...
# 95   413   5023                          Politeknik Negeri Malang
# 96   525   1061  Universitas Pembangunan Nasional Veteran Jakarta
# 97   448  11027         Universitas Muslim Nusantara Al-Washliyah
# 98  2106  71079              Universitas Nahdlatul Ulama Surabaya
# 99  2530  91004                 Universitas Muhammadiyah Makassar
#
#         abbreviation                                      location  \
# 0                UGM  KAB. SLEMAN - DAERAH ISTIMEWA YOGYAKARTA, ID
# ...
